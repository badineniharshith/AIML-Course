# %% [markdown]
# SOURCE :https://www.youtube.com/watch?v=ZftI2fEz0Fw&list=PLKnIA16_Rmvbr7zKYQuBfsVkjoLcJgxHH

# %%
import pandas as pd
import requests

# %% [markdown]
# get api from :https://developer.themoviedb.org/docs/getting-started

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     50.1445
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     32.2447
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     20.7783
# 3  The true story of how businessman Oskar Schind...   1993-12-15     19.6561
# 4  The defense and the prosecution have rested an...   1957-04-10     29.3511
#
#    vote_average  vote_count
# 0         8.712       28605
# 1         8.686       21655
# 2         8.571       13076
# 3         8.566       16579
# 4         8.550        9275

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd

df = pd.DataFrame()

for i in range(1, 429):
    url = f'https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}'
    response = requests.get(url)

    if response.status_code == 200:
        results = response.json().get('results', [])
        temp_df = pd.DataFrame(results)[['id', 'title', 'overview', 'release_date', 'popularity', 'vote_average', 'vote_count']]
        df = pd.concat([df, temp_df], ignore_index=True)
    else:
        print(f"Failed to fetch page {i}, status code: {response.status_code}")

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  290555                    Wolves
# 8556    9767              The Break-Up
# 8557  446131                    Madame
# 8558   86828       Absolutely Anything
# 8559    9982            Chicken Little
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  The coming-of-age story of Cayden Richards. Fo...   2014-08-28
# 8556  Pushed to the breaking-up point after their la...   2006-06-01
# 8557  Anne and Bob, a well-to-do American couple, ha...   2017-08-17
# 8558  Eccentric aliens give a man the power to do an...   2015-02-13
# 8559  When the sky really is falling and sanity has ...   2005-11-04
#
#       popularity  vote_average  vote_count
# 0        38.5399         8.712       28629
# 1        28.2502         8.686       21677
# 2        17.3499         8.571       13087
# 3        16.2378         8.600       16594
# 4        14.9400         8.549        9293
# ...          ...           ...         ...
# 8555      2.0954         5.899         308
# 8556      3.9402         5.899        2729
# 8557      1.4245         5.898         308
# 8558      2.3744         5.898        1515
# 8559      6.0285         5.898        3997
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
